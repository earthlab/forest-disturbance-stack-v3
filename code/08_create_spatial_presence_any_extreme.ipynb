# %%
### 08_create_spatial_presence_any_extreme

import rasterio
import numpy as np
import os

# -----------------------------
# Config
# -----------------------------
years = range(2000, 2021)

stack_templates = {
    "any": "../data/derived/annual_stacks/binary/annual_stack_any_{}.tif",
    "extreme": "../data/derived/annual_stacks/binary/annual_stack_extreme_{}.tif"
}

out_base = "../data/derived/annual_stacks/binary/spatial_presence"

bands = {
    "wf": 1,
    "bt": 2,
    "hd": 3,
    "pd": 4
}

# Only the combinations you requested
combos = {
    "wf_bt": ("wf", "bt"),
    "wf_hd": ("wf", "hd"),
    "wf_pd": ("wf", "pd"),
    "bt_hd": ("bt", "hd"),
    "bt_pd": ("bt", "pd"),
    "wf_bt_hd": ("wf", "bt", "hd"),
    "wf_bt_pd": ("wf", "bt", "pd"),
}

nodata_val = 0
pixel_area_km2 = (30 * 30) / 1e6

# -----------------------------
# Processing
# -----------------------------
for mode, template in stack_templates.items():
    print(f"\n==============================")
    print(f"Processing mode: {mode.upper()}")
    print(f"==============================")

    out_dir = f"{out_base}/{mode}"
    os.makedirs(out_dir, exist_ok=True)

    collapsed = {}
    meta = None

    # ---- Singles ----
    for name, band in bands.items():
        print(f"\nCollapsing {name} ({mode}) ...")
        arr_out = None

        for yr in years:
            f = template.format(yr)
            print(f"  Processing {f}")

            with rasterio.open(f) as src:
                arr = src.read(band).astype(np.uint8)

                if arr_out is None:
                    arr_out = arr.copy()
                    meta = src.meta.copy()
                    meta.update(
                        dtype=rasterio.uint8,
                        count=1,
                        compress='DEFLATE',
                        nodata=nodata_val,
                        tiled=True,
                        BIGTIFF='YES'
                    )
                else:
                    arr_out = ((arr_out > 0) | (arr > 0)).astype(np.uint8)

        out = f"{out_dir}/{name}_{mode}_presence.tif"
        with rasterio.open(out, "w", **meta) as dst:
            dst.write(arr_out, 1)

        px = np.count_nonzero(arr_out)
        area = px * pixel_area_km2

        print(f"  → {out}")
        print(f"    pixels: {px:,}")
        print(f"    area (km²): {area:,.2f}")

        collapsed[name] = arr_out

    # ---- Combinations ----
    print(f"\nCreating combinations ({mode})...")

    for cname, keys in combos.items():
        print(f"  Creating {cname}_{mode}_presence")

        combo = np.ones_like(collapsed[keys[0]], dtype=bool)
        for k in keys:
            combo &= (collapsed[k] > 0)

        combo = combo.astype(np.uint8)

        out = f"{out_dir}/{cname}_{mode}_presence.tif"
        with rasterio.open(out, "w", **meta) as dst:
            dst.write(combo, 1)

        px = np.count_nonzero(combo)
        area = px * pixel_area_km2

        print(f"  → {out}")
        print(f"    pixels: {px:,}")
        print(f"    area (km²): {area:,.2f}")

print("\n✅ ANY and EXTREME spatial presence rasters created with `_presence` suffix.")
# Out:
# ==============================
# Processing mode: ANY
# ==============================
#
# Collapsing wf (any) ...
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2000.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2001.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2002.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2003.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2004.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2005.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2006.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2007.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2008.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2009.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2010.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2011.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2012.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2013.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2014.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2015.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2016.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2017.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2018.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2019.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2020.tif
#   → ../data/derived/annual_stacks/binary/spatial_presence/any/wf_any.tif
#     pixels: 124,134,516
#     area (km²): 111,721.06
#
# Collapsing bt (any) ...
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2000.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2001.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2002.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2003.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2004.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2005.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2006.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2007.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2008.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2009.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2010.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2011.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2012.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2013.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2014.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2015.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2016.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2017.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2018.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2019.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2020.tif
#   → ../data/derived/annual_stacks/binary/spatial_presence/any/bt_any.tif
#     pixels: 504,333,753
#     area (km²): 453,900.38
#
# Collapsing hd (any) ...
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2000.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2001.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2002.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2003.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2004.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2005.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2006.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2007.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2008.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2009.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2010.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2011.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2012.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2013.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2014.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2015.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2016.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2017.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2018.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2019.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2020.tif
#   → ../data/derived/annual_stacks/binary/spatial_presence/any/hd_any.tif
#     pixels: 813,718,829
#     area (km²): 732,346.95
#
# Collapsing pd (any) ...
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2000.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2001.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2002.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2003.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2004.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2005.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2006.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2007.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2008.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2009.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2010.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2011.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2012.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2013.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2014.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2015.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2016.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2017.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2018.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2019.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_any_2020.tif
#   → ../data/derived/annual_stacks/binary/spatial_presence/any/pd_any.tif
#     pixels: 811,598,416
#     area (km²): 730,438.57
#
# Creating combinations (any)...
#   Creating wf_bt_any
#   → ../data/derived/annual_stacks/binary/spatial_presence/any/wf_bt_any.tif
#     pixels: 82,430,396
#     area (km²): 74,187.36
#   Creating wf_hd_any
#   → ../data/derived/annual_stacks/binary/spatial_presence/any/wf_hd_any.tif
#     pixels: 124,007,278
#     area (km²): 111,606.55
#   Creating wf_pd_any
#   → ../data/derived/annual_stacks/binary/spatial_presence/any/wf_pd_any.tif
#     pixels: 123,881,942
#     area (km²): 111,493.75
#   Creating bt_hd_any
#   → ../data/derived/annual_stacks/binary/spatial_presence/any/bt_hd_any.tif
#     pixels: 504,148,451
#     area (km²): 453,733.61
#   Creating bt_pd_any
#   → ../data/derived/annual_stacks/binary/spatial_presence/any/bt_pd_any.tif
#     pixels: 503,062,999
#     area (km²): 452,756.70
#   Creating wf_bt_hd_any
#   → ../data/derived/annual_stacks/binary/spatial_presence/any/wf_bt_hd_any.tif
#     pixels: 82,333,868
#     area (km²): 74,100.48
#   Creating wf_bt_pd_any
#   → ../data/derived/annual_stacks/binary/spatial_presence/any/wf_bt_pd_any.tif
#     pixels: 82,269,273
#     area (km²): 74,042.35
#
# ==============================
# Processing mode: EXTREME
# ==============================
#
# Collapsing wf (extreme) ...
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2000.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2001.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2002.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2003.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2004.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2005.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2006.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2007.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2008.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2009.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2010.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2011.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2012.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2013.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2014.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2015.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2016.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2017.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2018.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2019.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2020.tif
#   → ../data/derived/annual_stacks/binary/spatial_presence/extreme/wf_extreme.tif
#     pixels: 50,212,122
#     area (km²): 45,190.91
#
# Collapsing bt (extreme) ...
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2000.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2001.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2002.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2003.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2004.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2005.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2006.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2007.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2008.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2009.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2010.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2011.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2012.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2013.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2014.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2015.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2016.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2017.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2018.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2019.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2020.tif
#   → ../data/derived/annual_stacks/binary/spatial_presence/extreme/bt_extreme.tif
#     pixels: 3,412,212
#     area (km²): 3,070.99
#
# Collapsing hd (extreme) ...
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2000.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2001.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2002.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2003.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2004.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2005.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2006.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2007.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2008.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2009.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2010.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2011.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2012.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2013.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2014.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2015.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2016.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2017.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2018.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2019.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2020.tif
#   → ../data/derived/annual_stacks/binary/spatial_presence/extreme/hd_extreme.tif
#     pixels: 611,824,650
#     area (km²): 550,642.18
#
# Collapsing pd (extreme) ...
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2000.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2001.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2002.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2003.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2004.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2005.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2006.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2007.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2008.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2009.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2010.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2011.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2012.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2013.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2014.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2015.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2016.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2017.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2018.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2019.tif
#   Processing ../data/derived/annual_stacks/binary/annual_stack_extreme_2020.tif
#   → ../data/derived/annual_stacks/binary/spatial_presence/extreme/pd_extreme.tif
#     pixels: 385,758,953
#     area (km²): 347,183.06
#
# Creating combinations (extreme)...
#   Creating wf_bt_extreme
#   → ../data/derived/annual_stacks/binary/spatial_presence/extreme/wf_bt_extreme.tif
#     pixels: 410,052
#     area (km²): 369.05
#   Creating wf_hd_extreme
#   → ../data/derived/annual_stacks/binary/spatial_presence/extreme/wf_hd_extreme.tif
#     pixels: 34,388,771
#     area (km²): 30,949.89
#   Creating wf_pd_extreme
#   → ../data/derived/annual_stacks/binary/spatial_presence/extreme/wf_pd_extreme.tif
#     pixels: 21,294,240
#     area (km²): 19,164.82
#   Creating bt_hd_extreme
#   → ../data/derived/annual_stacks/binary/spatial_presence/extreme/bt_hd_extreme.tif
#     pixels: 2,184,739
#     area (km²): 1,966.27
#   Creating bt_pd_extreme
#   → ../data/derived/annual_stacks/binary/spatial_presence/extreme/bt_pd_extreme.tif
#     pixels: 2,369,936
#     area (km²): 2,132.94
#   Creating wf_bt_hd_extreme
#   → ../data/derived/annual_stacks/binary/spatial_presence/extreme/wf_bt_hd_extreme.tif
#     pixels: 340,460
#     area (km²): 306.41
#   Creating wf_bt_pd_extreme
#   → ../data/derived/annual_stacks/binary/spatial_presence/extreme/wf_bt_pd_extreme.tif
#     pixels: 274,301
#     area (km²): 246.87
#
# ✅ ANY and EXTREME spatial presence rasters created successfully.
